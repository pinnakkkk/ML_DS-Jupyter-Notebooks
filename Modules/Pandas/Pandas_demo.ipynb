# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt

# %matplotlib inline

df = pd.read_csv('/home/lazylinuxer/py-Jupyter-notebook/DataSets/Hong_Kong_RainStorm_Record.csv')
print(df)
# Out:
#      color start time start date end time   end date duration
# 0    Amber       5:15  12-Apr-98     8:00  12-Apr-98    02 45
# 1    Amber      21:15  26-Apr-98    21:50  26-Apr-98    00 35
# 2      Red      21:50  26-Apr-98     4:00  27-Apr-98    06 10
# 3    Amber       4:00  27-Apr-98     5:45  27-Apr-98    01 45
# 4    Amber      16:20   2-May-98    17:50   2-May-98    01 30
# ..     ...        ...        ...      ...        ...      ...
# 716  Amber      19:30  14-Jun-22    20:45  14-Jun-22    01 15
# 717  Amber      19:30  15-Jun-22    21:40  15-Jun-22    02 10
# 718  Amber       0:50   1-Jul-22     2:10   1-Jul-22    01 20
# 719  Amber      15:15   1-Jul-22    17:15   1-Jul-22    02 00
# 720  Amber      10:00  30-Jul-22    11:30  30-Jul-22    01 30
#
# [721 rows x 6 columns]

# %%
df.info() 
#Dtype: Object means str or mix
#non-null count is 721 (all) are non-null
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 721 entries, 0 to 720
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   color       721 non-null    object
#  1   start time  721 non-null    object
#  2   start date  721 non-null    object
#  3   end time    721 non-null    object
#  4   end date    721 non-null    object
#  5   duration    721 non-null    object
# dtypes: object(6)
# memory usage: 33.9+ KB

# %%
df.shape
# Out:
# (721, 6)

# %%
df.tail(20)
# Out:
#      color start time start date end time   end date duration
# 701  Amber      17:45   8-Oct-21    19:25   8-Oct-21    01 40
# 702  Amber      13:00   9-Oct-21    21:05   9-Oct-21    08 05
# 703  Amber      14:02  13-Oct-21    17:10  13-Oct-21    03 08
# 704  Amber       5:25  12-May-22     6:40  12-May-22    01 15
# 705  Amber      12:10  12-May-22    22:45  12-May-22    10 35
# 706  Amber       3:55  13-May-22     4:25  13-May-22    00 30
# 707    Red       4:25  13-May-22     7:05  13-May-22    02 40
# 708  Amber       7:05  13-May-22     7:40  13-May-22    00 35
# 709  Amber      19:05  13-May-22    22:30  13-May-22    03 25
# 710  Amber       3:45   7-Jun-22     6:40   7-Jun-22    02 55
# 711  Amber      19:35   7-Jun-22    20:45   7-Jun-22    01 10
# 712  Amber       9:45   8-Jun-22    10:45   8-Jun-22    01 00
# 713    Red      10:45   8-Jun-22    16:15   8-Jun-22    05 30
# 714  Amber      16:15   8-Jun-22    17:15   8-Jun-22    01 00
# ...

# %%
type(df["color"])
# Out:
# pandas.core.series.Series

# %%
#index specific items in a tuple or list (or in general, any sequence) eg a[1]

df.loc[720, :'duration']
# Out:
# color             Amber
# start time        10:00
# start date    30-Jul-22
# end time          11:30
# end date      30-Jul-22
# duration          01 30
# Name: 720, dtype: object

# %%
df.iloc[720, 0:]
# Out:
# color             Amber
# start time        10:00
# start date    30-Jul-22
# end time          11:30
# end date      30-Jul-22
# duration          01 30
# Name: 720, dtype: object

# %%
df['color'].unique()
# Out:
# array(['Amber', 'Red', 'Black'], dtype=object)

# %%
plt.hist(df['color'], bins = 5)
# Out:
# (array([579.,   0., 117.,   0.,  25.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. ]),
#  <BarContainer object of 5 artists>)

# %%
df
# Out:
#      color start time start date end time   end date duration
# 0    Amber       5:15  12-Apr-98     8:00  12-Apr-98    02 45
# 1    Amber      21:15  26-Apr-98    21:50  26-Apr-98    00 35
# 2      Red      21:50  26-Apr-98     4:00  27-Apr-98    06 10
# 3    Amber       4:00  27-Apr-98     5:45  27-Apr-98    01 45
# 4    Amber      16:20   2-May-98    17:50   2-May-98    01 30
# ..     ...        ...        ...      ...        ...      ...
# 716  Amber      19:30  14-Jun-22    20:45  14-Jun-22    01 15
# 717  Amber      19:30  15-Jun-22    21:40  15-Jun-22    02 10
# 718  Amber       0:50   1-Jul-22     2:10   1-Jul-22    01 20
# 719  Amber      15:15   1-Jul-22    17:15   1-Jul-22    02 00
# 720  Amber      10:00  30-Jul-22    11:30  30-Jul-22    01 30
#
# [721 rows x 6 columns]

# %%
df['start date'] = pd.to_datetime(df['start date'])
df['end date'] = pd.to_datetime(df['end date'])
df
# Out:
#      color start time start date end time   end date duration
# 0    Amber       5:15 1998-04-12     8:00 1998-04-12    02 45
# 1    Amber      21:15 1998-04-26    21:50 1998-04-26    00 35
# 2      Red      21:50 1998-04-26     4:00 1998-04-27    06 10
# 3    Amber       4:00 1998-04-27     5:45 1998-04-27    01 45
# 4    Amber      16:20 1998-05-02    17:50 1998-05-02    01 30
# ..     ...        ...        ...      ...        ...      ...
# 716  Amber      19:30 2022-06-14    20:45 2022-06-14    01 15
# 717  Amber      19:30 2022-06-15    21:40 2022-06-15    02 10
# 718  Amber       0:50 2022-07-01     2:10 2022-07-01    01 20
# 719  Amber      15:15 2022-07-01    17:15 2022-07-01    02 00
# 720  Amber      10:00 2022-07-30    11:30 2022-07-30    01 30
#
# [721 rows x 6 columns]

# %%
# plot line chart, y = duration & x = start date

# plt.plot(df['start date'], df['end date'])

# df['duration'] = df['duration'] + ' 00'
df
# Out:
#      color start time start date end time   end date            duration  \
# 0    Amber       5:15 1998-04-12     8:00 1998-04-12 1900-01-01 02:45:00
# 1    Amber      21:15 1998-04-26    21:50 1998-04-26 1900-01-01 00:35:00
# 2      Red      21:50 1998-04-26     4:00 1998-04-27 1900-01-01 06:10:00
# 3    Amber       4:00 1998-04-27     5:45 1998-04-27 1900-01-01 01:45:00
# 4    Amber      16:20 1998-05-02    17:50 1998-05-02 1900-01-01 01:30:00
# ..     ...        ...        ...      ...        ...                 ...
# 716  Amber      19:30 2022-06-14    20:45 2022-06-14 1900-01-01 01:15:00
# 717  Amber      19:30 2022-06-15    21:40 2022-06-15 1900-01-01 02:10:00
# 718  Amber       0:50 2022-07-01     2:10 2022-07-01 1900-01-01 01:20:00
# 719  Amber      15:15 2022-07-01    17:15 2022-07-01 1900-01-01 02:00:00
# 720  Amber      10:00 2022-07-30    11:30 2022-07-30 1900-01-01 01:30:00
#
#     duration_time
# 0        02:45:00
# 1        00:35:00
# 2        06:10:00
# ...

# %%
# df['duration'] = df['duration'].str.replace(' ', ':')

# df['duration'] = pd.to_datetime(df['duration'], format = '%H:%M:%S')
df['duration_time'] = df['duration'].dt.time
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 721 entries, 0 to 720
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   color          721 non-null    object
#  1   start time     721 non-null    object
#  2   start date     721 non-null    datetime64[ns]
#  3   end time       721 non-null    object
#  4   end date       721 non-null    datetime64[ns]
#  5   duration       721 non-null    datetime64[ns]
#  6   duration_time  721 non-null    object
# dtypes: datetime64[ns](3), object(4)
# memory usage: 39.6+ KB

# %%
df['duration_time'].apply(pd.to_datetime, infer_datetime_format=True, errors='coerce')
# Out:
# 0     NaT
# 1     NaT
# 2     NaT
# 3     NaT
# 4     NaT
#        ..
# 716   NaT
# 717   NaT
# 718   NaT
# 719   NaT
# 720   NaT
# Name: duration_time, Length: 721, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 721 entries, 0 to 720
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   color          721 non-null    object
#  1   start time     721 non-null    object
#  2   start date     721 non-null    datetime64[ns]
#  3   end time       721 non-null    object
#  4   end date       721 non-null    datetime64[ns]
#  5   duration       721 non-null    datetime64[ns]
#  6   duration_time  721 non-null    object
# dtypes: datetime64[ns](3), object(4)
# memory usage: 39.6+ KB

# %%
df
# Out:
#      color start time start date end time   end date            duration  \
# 0    Amber       5:15 1998-04-12     8:00 1998-04-12 1900-01-01 02:45:00
# 1    Amber      21:15 1998-04-26    21:50 1998-04-26 1900-01-01 00:35:00
# 2      Red      21:50 1998-04-26     4:00 1998-04-27 1900-01-01 06:10:00
# 3    Amber       4:00 1998-04-27     5:45 1998-04-27 1900-01-01 01:45:00
# 4    Amber      16:20 1998-05-02    17:50 1998-05-02 1900-01-01 01:30:00
# ..     ...        ...        ...      ...        ...                 ...
# 716  Amber      19:30 2022-06-14    20:45 2022-06-14 1900-01-01 01:15:00
# 717  Amber      19:30 2022-06-15    21:40 2022-06-15 1900-01-01 02:10:00
# 718  Amber       0:50 2022-07-01     2:10 2022-07-01 1900-01-01 01:20:00
# 719  Amber      15:15 2022-07-01    17:15 2022-07-01 1900-01-01 02:00:00
# 720  Amber      10:00 2022-07-30    11:30 2022-07-30 1900-01-01 01:30:00
#
#     duration_time
# 0        02:45:00
# 1        00:35:00
# 2        06:10:00
# ...
